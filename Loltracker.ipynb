# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import json


DRIVER_PATH = './chromedriver'
BASE_URL = 'https://loltracker.com/'

driver = webdriver.Chrome(DRIVER_PATH)
driver.get(BASE_URL)

#driver.maximize_window()

articles = driver.find_element(By.CLASS_NAME, 'view-all-blogs')
articles.find_element(By.TAG_NAME, 'a').click()

selections = driver.find_elements(By.CLASS_NAME, 'eb-post-listing__item')
data = {}
cpt = 0

for element in selections:
    data_temp = {}
    try:
        data_temp['title'] = element.text.split('\n')[0]
    except:
        data_temp['title'] = None
    try:
        data_temp['date'] = element.text.split('\n')[1]
    except:
        data_temp['date'] = None
    try:
        data_temp['author'] = element.text.split('\n')[2]
    except:
        data_temp['author'] = None
    try:
        data_temp['desc'] = element.text.split('\n')[3]
    except:
        data_temp['desc'] = None
    try:
        data_temp['keys'] = '-'.join(element.text.split('\n')[5:])
    except:
        data_temp['keys'] = None
    try:
        data_temp['img'] = element.find_element(By.CLASS_NAME, 'eb-post-thumb.is-left').find_element(By.TAG_NAME,'img').get_attribute('src')
    except:
        data_temp['img']  
        
    data[cpt] = data_temp
    cpt+=1

with open("loltracker.json", "wb") as f:
    f.write(str(data).encode("UTF-8"))
    
driver.close()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_38900\2390596737.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(DRIVER_PATH)

# %%
with open('loltracker.json', 'w', encoding='utf8') as f:
    json.dump(data, f, indent=2)

# %%
with open('loltracker.json', 'w', encoding='utf8') as f:
    f.write(str(data))

# %%
with open('loltracker.json') as f:
    data2 = json.load(f)

# %%
with open("filename.txt", "wb") as f:
    f.write(str(data).encode("UTF-8"))

# %%
data
# Out:
# {0: {'title': 'Mise à jour sur le PBE (21/10)',
#   'date': 'samedi 22 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Malzahar_Splash__20160429-180710_1.jpg'},
#  1: {'title': "Aperçu de K'Santé",
#   'date': 'samedi 22 octobre 2022',
#   'author': 'Philidia',
#   'desc': "L'homme bien bâti de Nazumah.",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7728/b2ap3_thumbnail_00_ksanteinsights_Header.jpg'},
#  2: {'title': 'Mise à jour sur le PBE (18/10)',
#   'date': 'mercredi 19 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant K'Santé le nouveau champion, et de nouveaux skins et contenus cosmétiques",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7727/b2ap3_thumbnail_FfXYUgzXgAIOAZi.jpg'},
#  3: {'title': 'Notes de patch 12.20',
#   'date': 'mardi 18 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'Dans ce patch : des nerfs qui font peur, des buffs enchanteurs et des skins ensorceleurs !',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_01_Banner_New_Champ_Balance-min.jpg'},
#  4: {'title': 'Notes de patch 12.20 de Teamfight Tactics',
#   'date': 'mardi 18 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Au programme : Ashe dracomancienne chibi, le rééquilibrage de quelques optimisations, la liste d'amis sur mobile et plus encore.",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_tftnews_0.jpg'},
#  5: {'title': 'Preview de skins : Lignée Empyréens',
#   'date': 'mardi 18 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Déjà dévoilés lundi, Riot a formalisé son annonce de nouveaux skins pour Jax, Jhin, K'Sante (+Prestige), Lux, Pyke, Vex, Zac et Zed !",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7724/b2ap3_thumbnail_FfXHdTkWAAIEc97.jpg'},
#  6: {'title': 'Empyréens 2022 | Bande-annonce des skins',
#   'date': 'lundi 17 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Préparez-vous à combattre dans plusieurs dimensions avec Pyke, Jax, Vex, Zac, Zed, Jhin, Lux et K'Santé empyréens le 3 novembre.",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7723/b2ap3_thumbnail_FfD4pzMXEAECmOR-1-1.jpg'},
#  7: {'title': 'Détails des compétences de K’Santé',
#   'date': 'dimanche 16 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'Partez au combat avec la Fierté de Nazumah au patch 12.21.',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7722/b2ap3_thumbnail_K_Sante-Base-Splash.jpg'},
#  8: {'title': "K'Santé, Fierté de Nazumah - Bande-annonce de gameplay",
#   'date': 'dimanche 16 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'Du bouclier robuste à la lame intrépide : devenez la personne dont ils ont besoin.',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7721/b2ap3_thumbnail_maxresdefault-4.jpg'},
#  9: {'title': "Vainquez votre démon - Cinématique de K'Santé",
#   'date': 'vendredi 14 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Les maux d'hier deviennent les armes de demain. Prenez-en de la graine, car la chasse continue.",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7720/b2ap3_thumbnail_maxresdefault-3.jpg'},
#  10: {'title': 'Récompenses classées 2022',
#   'date': 'vendredi 14 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'La saison 2022 se termine le 14 novembre !',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7719/b2ap3_thumbnail_Lol_Victorious-Sejuani.jpg'},
#  11: {'title': "Fierté du chasseur - Teaser de K'Santé",
#   'date': 'jeudi 13 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Dès la venue de l'aube, K'Santé est prêt à partir à l'aventure.",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7718/b2ap3_thumbnail_Fe9FJFiWQAEuvfJ.jpg'},
#  12: {'title': 'Mise à jour sur le PBE (10/10)',
#   'date': 'mardi 11 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_Ask_Riot_Items_Banner.jpg'},
#  13: {'title': 'Mise à jour sur le PBE (04/10 - Présaison)',
#   'date': 'mardi 4 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'Une nouvelle mise à jour a eu lieu sur le PBE, apportant de nouveaux skins, le contenu de la présaison, et bien plus !',
#   'keys': 'Présaison-PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7712/b2ap3_thumbnail_006f8wK2ly1h6t9ja35oyj61e00u0ahj02.jpg'},
#  14: {'title': 'Preview de skins : Bewitching 2022 & Three Honors',
#   'date': 'mardi 4 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'De nouveaux skins ont été dévoilés par Riot, pour Anivia, Senna, Cassiopeia, LeBlanc, Neeko, et Malzahar !',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7715/b2ap3_thumbnail_006f8wK2ly1h6t9ja5dzpj61he0u0wh902.jpg'},
#  15: {'title': 'Notes de patch 12.19',
#   'date': 'mardi 4 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'Des buffs pour Blitzcrank combattant ? Des buffs pour Rakan AP ? Est-ce un rêve, ou est-ce le patch 12.19 ? Bienvenue dans le patch des buffs hors méta !',
#   'keys': 'Patchnotes',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_01_Banner_New_Champ_Balance-min.jpg'},
#  16: {'title': 'Notes de patch 12.19 de Teamfight Tactics',
#   'date': 'mardi 4 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Événement Secrets des océans, changement pour Brise-écaille et nouveau palier Dragon (6) ! Le patch 12.19 va mettre le feu (et l'eau) !",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_tftnews_0.jpg'},
#  17: {'title': 'Aperçu de la présaison 2023',
#   'date': 'lundi 3 octobre 2022',
#   'author': 'Philidia',
#   'desc': 'Un guide de référence pratique et rapide pour tout le contenu de la présaison 2023 sur le PBE.',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7711/b2ap3_thumbnail_100322_Preseason_2023_Logo_Banner.jpg'},
#  18: {'title': "/dev : MID d'Ahri",
#   'date': 'dimanche 2 octobre 2022',
#   'author': 'Philidia',
#   'desc': "Nom d'un renard, où est la mise à jour d'Ahri ?",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7710/b2ap3_thumbnail_09262022_AhrisASUDevArticle_00_HEADER_wider.jpg'},
#  19: {'title': 'Résultat du concours de pronostics des LEC + Concours des Worlds',
#   'date': 'jeudi 29 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Résultats du concours de pronostics des LEC, et détails pour celui des championnats du monde !',
#   'keys': 'Concours de pronostics',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_sona3b_by_holyelfgirl_ddcwp38.jpg'},
#  20: {'title': 'Mise à jour sur le PBE (28/09)',
#   'date': 'jeudi 29 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Udyr.jpg'},
#  21: {'title': 'Mise à jour sur le PBE (27/09)',
#   'date': 'mercredi 28 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant principalement de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Nasus_0.jpg'},
#  22: {'title': 'Mise à jour sur le PBE (22/09)',
#   'date': 'vendredi 23 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant principalement de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Syndra_Splash_0.jpg'},
#  23: {'title': 'Mise à jour sur le PBE (20/09)',
#   'date': 'mercredi 21 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de nouveaux skins, une mise à jour des effets visuels de Janna, de l'équilibrage pour Syndra, et bien plus !",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7705/b2ap3_thumbnail_sett.jpg'},
#  24: {'title': 'Preview de skins : Lignée fleur spirituelle 2022',
#   'date': 'mardi 20 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'De nouveaux skins ont été dévoilés par Riot, pour Aphelios, Darius, Evelynn, Maître Yi (+Prestige), Sett, Soraka, Syndra, Tristana, et Yorick !',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7704/b2ap3_thumbnail_masteryiprestige.jpg'},
#  25: {'title': 'Notes de patch 12.18',
#   'date': 'mardi 20 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Bienvenue dans le patch 12.18, le patch du Mondial 2022 !',
#   'keys': 'Patchnotes',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_01_Banner_New_Champ_Balance-min.jpg'},
#  26: {'title': 'Notes de patch 12.18 de Teamfight Tactics',
#   'date': 'mardi 20 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Le patch 12.18 est le premier de l'ensemble Royaumes inconnus ! Son objectif premier est d'apporter des buffs aux compos en difficulté, y compris celles de relance.",
#   'keys': 'Patchnotes-TFT',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_tftnews_0.jpg'},
#  27: {'title': 'Esprits errants | Bande-annonce Fleur spirituelle 2022',
#   'date': 'vendredi 16 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Nouvelle année, nouveau voyage. Suivez Sett dans sa quête annuelle pour retrouver son père.',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7701/b2ap3_thumbnail_maxresdefault-2.jpg'},
#  28: {'title': 'Mise à jour sur le PBE (14/09)',
#   'date': 'jeudi 15 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Hecarim_Splash_0.jpg'},
#  29: {'title': 'Mise à jour sur le PBE (13/09)',
#   'date': 'mercredi 14 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant principalement de l'équilibrage !",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Udyr.jpg'},
#  30: {'title': 'Mise à jour sur le PBE (08/09)',
#   'date': 'vendredi 9 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Une nouvelle mise à jour a eu lieu sur le PBE, apportant artworks, icônes, et émotes !',
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7698/b2ap3_thumbnail_268014.jpg'},
#  31: {'title': 'Mise à jour sur le PBE (07/09)',
#   'date': 'jeudi 8 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Une nouvelle mise à jour a eu lieu sur le PBE, apportant beaucoup de nouveaux skins et de contenu cosmétique !',
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7697/b2ap3_thumbnail_1031.jpg'},
#  32: {'title': 'Notes de patch 12.17',
#   'date': 'mercredi 7 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Bienvenue dans l'avant-dernier patch avant le Mondial !",
#   'keys': 'Patchnotes',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_01_Banner_New_Champ_Balance-min.jpg'},
#  33: {'title': 'Notes de patch 12.17 de Teamfight Tactics',
#   'date': 'mercredi 7 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Bienvenue dans Royaumes inconnus ! Vous y trouverez de nouvelles unités, de nouveaux types, de nouvelles mécaniques, de nouveaux Tacticiens... et des dragons !',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_tftnews_0.jpg'},
#  34: {'title': 'Preview de skin : Ashen Knight Sylas',
#   'date': 'mercredi 7 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Un nouveau skin a été dévoilé par Riot, pour Sylas !',
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7694/b2ap3_thumbnail_maxresdefault-1.jpg'},
#  35: {'title': "Récompenses d'Honneur mises à jour",
#   'date': 'lundi 5 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Découvrez les skins d'Honneur.",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_articles/7693/b2ap3_thumbnail_Honor_Skin_Banner_opt.jpg'},
#  36: {'title': "RedTracker #378 : L'équilibrage de Zeri et Yuumi",
#   'date': 'dimanche 4 septembre 2022',
#   'author': 'Philidia',
#   'desc': 'Thèmes abordés : Équilibrage de Zeri et Yuumi, pause dans les pensées sur le gameplay, et bien plus !',
#   'keys': 'RedTracker',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_RedTracker2019.jpg'},
#  37: {'title': 'Mise à jour sur le PBE (31/08)',
#   'date': 'jeudi 1 septembre 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Hecarim_Splash_0.jpg'},
#  38: {'title': 'Mise à jour sur le PBE (30/08)',
#   'date': 'mercredi 31 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Rell_0.jpg'},
#  39: {'title': 'Mise à jour sur le PBE (29/08)',
#   'date': 'mardi 30 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_MissFortune_Splash_0.jpg'},
#  40: {'title': 'Mise à jour sur le PBE (26/08)',
#   'date': 'samedi 27 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': '',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_Ask_Riot_Items_Banner.jpg'},
#  41: {'title': 'Mise à jour sur le PBE (25/08)',
#   'date': 'vendredi 26 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant un nouvel artwork, et de l'équilibrage pour Maokai",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7686/b2ap3_thumbnail_126025.jpg'},
#  42: {'title': 'Mise à jour sur le PBE (24/08)',
#   'date': 'jeudi 25 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage pour Maokai",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Maokai_0.jpg'},
#  43: {'title': '/Dev TFT : Ici sont les dragons',
#   'date': 'mercredi 24 août 2022',
#   'author': 'Philidia',
#   'desc': 'Riot Mort évoque tous les changements des Dragons et du Dragon précieux dans Royaumes inconnus.',
#   'keys': 'TFT',
#   'img': 'https://loltracker.com/images/easyblog_articles/7683/b2ap3_thumbnail_08232022_Comms_Mechanics-Update_Banner.jpg'},
#  44: {'title': "Passe TFT : L'ère des dragons II et bien plus",
#   'date': 'mercredi 24 août 2022',
#   'author': 'Philidia',
#   'desc': "Tout ce que vous devez savoir sur les Tacticiens, les arènes et le passe de L'ère des dragons !",
#   'keys': 'TFT',
#   'img': 'https://loltracker.com/images/easyblog_articles/7682/b2ap3_thumbnail_TFT_MID722_Comms_PassMore_Article-Banner_1920x1080_v001_ALyu.jpg'},
#  45: {'title': 'Mise à jour sur le PBE (23/08)',
#   'date': 'mercredi 24 août 2022',
#   'author': 'Philidia',
#   'desc': 'Une nouvelle mise à jour a eu lieu sur le PBE, apportant de nouveaux skins, le nouvel ensemble TFT, et divers contenus cosmétiques',
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7684/b2ap3_thumbnail_53047.jpg'},
#  46: {'title': 'Notes de patch 12.16',
#   'date': 'mardi 23 août 2022',
#   'author': 'Philidia',
#   'desc': 'Libérez les esprits et découvrez de nouveaux nerfs et buffs dans le patch 12.16 !',
#   'keys': 'Patchnotes',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_01_Banner_New_Champ_Balance-min.jpg'},
#  47: {'title': 'Notes de patch 12.16 de Teamfight Tactics',
#   'date': 'mardi 23 août 2022',
#   'author': 'Philidia',
#   'desc': "Le patch 12.16 est le dernier avant Royaumes inconnus, l'ensemble de mi-parcours qui va apporter de nombreux changements !",
#   'keys': 'Patchnotes-TFT',
#   'img': 'https://loltracker.com/images/easyblog_images/576/b2ap3_thumbnail_tftnews_0.jpg'},
#  48: {'title': 'Mise à jour sur le PBE (18/08)',
#   'date': 'vendredi 19 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_shared/Champion_splash/b2ap3_thumbnail_Jayce_Splash_0.jpg'},
#  49: {'title': 'Mise à jour sur le PBE (16/08)',
#   'date': 'mercredi 17 août 2022',
#   'author': 'Philidia',
#   'desc': "Une nouvelle mise à jour a eu lieu sur le PBE, apportant une mise à jour d'artwork, et de l'équilibrage",
#   'keys': 'PBE',
#   'img': 'https://loltracker.com/images/easyblog_articles/7678/b2ap3_thumbnail_164021.jpg'}}
